# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import math

from matplotlib.font_manager import FontProperties

from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_percentage_error

# %%
# dataset
training_data_file = '/Users/jellyfish/Desktop/T-Brain/30_Training Dataset_V2/training_data.csv'
pu_testing_data_file = '/Users/jellyfish/Desktop/T-Brain/30_Public Dataset_Public Sumission Template_v2/public_dataset.csv'
pr_testing_data_file = '/Users/jellyfish/Desktop/T-Brain/30_Private Dataset _Private and Publict Submission Template_v2/private_dataset.csv'
testing_submit = '/Users/jellyfish/Desktop/T-Brain/30_Private Dataset _Private and Publict Submission Template_v2/public_private_submission_template.csv'
submit_file = '/Users/jellyfish/Desktop/T-Brain/submission/submission.csv'

# external data
train_file = "/Users/jellyfish/Desktop/T-Brain/30_Training Dataset_V2/external_data/火車站點資料.csv"
bus_file = "/Users/jellyfish/Desktop/T-Brain/30_Training Dataset_V2/external_data/公車站點資料.csv"
mrt_file = "/Users/jellyfish/Desktop/T-Brain/30_Training Dataset_V2/external_data/捷運站點資料.csv"
con_file = "/Users/jellyfish/Desktop/T-Brain/30_Training Dataset_V2/external_data/便利商店.csv"
ele_file = "/Users/jellyfish/Desktop/T-Brain/30_Training Dataset_V2/external_data/國小基本資料.csv"
jun_file = "/Users/jellyfish/Desktop/T-Brain/30_Training Dataset_V2/external_data/國中基本資料.csv"
high_file = "/Users/jellyfish/Desktop/T-Brain/30_Training Dataset_V2/external_data/高中基本資料.csv"
uni_file = "/Users/jellyfish/Desktop/T-Brain/30_Training Dataset_V2/external_data/大學基本資料.csv"
fin_file = "/Users/jellyfish/Desktop/T-Brain/30_Training Dataset_V2/external_data/金融機構基本資料.csv"
hos_file = "/Users/jellyfish/Desktop/T-Brain/30_Training Dataset_V2/external_data/醫療機構基本資料.csv"

# Read data
train_df = pd.read_csv(training_data_file)
pu_test_df = pd.read_csv(pu_testing_data_file)
pr_test_df = pd.read_csv(pr_testing_data_file)
test_sb = pd.read_csv(testing_submit)
train_extra = pd.read_csv(train_file)
bus_extra = pd.read_csv(bus_file)
mrt_extra = pd.read_csv(mrt_file)
con_extra = pd.read_csv(con_file)
ele_extra = pd.read_csv(ele_file)
jun_extra = pd.read_csv(jun_file)
high_extra = pd.read_csv(high_file)
fin_extra = pd.read_csv(fin_file)
hos_extra = pd.read_csv(hos_file)
uni_extra = pd.read_csv(uni_file)


test_df = pd.concat([pu_test_df, pr_test_df], axis=0)
test_df.reset_index(drop=True, inplace=True)

# %%
# loss function
def mape_loss(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def lonlat_to_97(lon,lat):
    """
    It transforms longitude, latitude to TWD97 system.

    Parameters
    ----------
    lon : float
        longitude in degrees
    lat : float
        latitude in degrees

    Returns
    -------
    x, y [TWD97]
    """

    lat = math.radians(lat)
    lon = math.radians(lon)

    a = 6378137.0
    b = 6356752.314245
    long0 = math.radians(121)
    k0 = 0.9999
    dx = 250000

    e = (1-b**2/a**2)**0.5
    e2 = e**2/(1-e**2)
    n = (a-b)/(a+b)
    nu = a/(1-(e**2)*(math.sin(lat)**2))**0.5
    p = lon-long0

    A = a*(1 - n + (5/4.0)*(n**2 - n**3) + (81/64.0)*(n**4  - n**5))
    B = (3*a*n/2.0)*(1 - n + (7/8.0)*(n**2 - n**3) + (55/64.0)*(n**4 - n**5))
    C = (15*a*(n**2)/16.0)*(1 - n + (3/4.0)*(n**2 - n**3))
    D = (35*a*(n**3)/48.0)*(1 - n + (11/16.0)*(n**2 - n**3))
    E = (315*a*(n**4)/51.0)*(1 - n)

    S = A*lat - B*math.sin(2*lat) + C*math.sin(4*lat) - D*math.sin(6*lat) + E*math.sin(8*lat)

    K1 = S*k0
    K2 = k0*nu*math.sin(2*lat)/4.0
    K3 = (k0*nu*math.sin(lat)*(math.cos(lat)**3)/24.0) * (5 - math.tan(lat)**2 + 9*e2*(math.cos(lat)**2) + 4*(e2**2)*(math.cos(lat)**4))

    y_97 = K1 + K2*(p**2) + K3*(p**4)

    K4 = k0*nu*math.cos(lat)
    K5 = (k0*nu*(math.cos(lat)**3)/6.0) * (1 - math.tan(lat)**2 + e2*(math.cos(lat)**2))

    x_97 = K4*p + K5*(p**3) + dx
    return x_97, y_97

# %%
def twd97_to_lonlat(x,y):
    """
    Parameters
    ----------
    x : float
        TWD97 coord system. The default is 174458.0.
    y : float
        TWD97 coord system. The default is 2525824.0.
    Returns
    -------
    list
        [longitude, latitude]
    """

    a = 6378137
    b = 6356752.314245
    long_0 = 121 * math.pi / 180.0
    k0 = 0.9999
    dx = 250000
    dy = 0

    e = math.pow((1-math.pow(b, 2)/math.pow(a,2)), 0.5)

    x = x - dx
    y = y - dy

    M = y / k0

    mu = M / ( a*(1-math.pow(e, 2)/4 - 3*math.pow(e,4)/64 - 5 * math.pow(e, 6)/256))
    e1 = (1.0 - pow((1   - pow(e, 2)), 0.5)) / (1.0 +math.pow((1.0 -math.pow(e,2)), 0.5))

    j1 = 3*e1/2-27*math.pow(e1,3)/32
    j2 = 21 * math.pow(e1,2)/16 - 55 * math.pow(e1, 4)/32
    j3 = 151 * math.pow(e1, 3)/96
    j4 = 1097 * math.pow(e1, 4)/512

    fp = mu + j1 * math.sin(2*mu) + j2 * math.sin(4* mu) + j3 * math.sin(6*mu) + j4 * math.sin(8* mu)

    e2 = math.pow((e*a/b),2)
    c1 = math.pow(e2*math.cos(fp),2)
    t1 = math.pow(math.tan(fp),2)
    r1 = a * (1-math.pow(e,2)) / math.pow( (1-math.pow(e,2)* math.pow(math.sin(fp),2)), (3/2))
    n1 = a / math.pow((1-math.pow(e,2)*math.pow(math.sin(fp),2)),0.5)
    d = x / (n1*k0)

    q1 = n1* math.tan(fp) / r1
    q2 = math.pow(d,2)/2
    q3 = ( 5 + 3 * t1 + 10 * c1 - 4 * math.pow(c1,2) - 9 * e2 ) * math.pow(d,4)/24
    q4 = (61 + 90 * t1 + 298 * c1 + 45 * math.pow(t1,2) - 3 * math.pow(c1,2) - 252 * e2) * math.pow(d,6)/720
    lat = fp - q1 * (q2 - q3 + q4)


    q5 = d
    q6 = (1+2*t1+c1) * math.pow(d,3) / 6
    q7 = (5 - 2 * c1 + 28 * t1 - 3 * math.pow(c1,2) + 8 * e2 + 24 * math.pow(t1,2)) * math.pow(d,5) / 120
    lon = long_0 + (q5 - q6 + q7) / math.cos(fp)

    lat = (lat*180) / math.pi
    lon = (lon*180) / math.pi
    return [lon, lat]

# %%
def transform_lat(extra_data):
    trans_x = []
    trans_y = []
    for i in range(len(extra_data)):
        x,y = lonlat_to_97(extra_data['lng'][i],extra_data['lat'][i])
        trans_x.append(x)
        trans_y.append(y)
    return trans_x,trans_y

# %%
def haversine(lat1,long1,lat2,long2):
    R = 6371  #radius of earth in kilometers
    phi1 = np.radians(lat1)
    phi2 = np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(long2 - long1)

    #a = sin²((φB - φA)/2) + cos φA . cos φB . sin²((λB - λA)/2)
    a = np.sin(delta_phi / 2.0) ** 2 + np.cos(phi1) * np.cos(phi2) * np.sin(delta_lambda / 2.0) ** 2

    #c = 2 * atan2( √a, √(1−a) )
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))

    #d = R*c
    d = (R * c) #in kilometers
    return d

# %%
def compute_distance(long1,lat1,train_x,train_y):
    long2,lat2 = twd97_to_lonlat(train_x,train_y)
    d = haversine(lat1,long1,lat2,long2)
    return d

# %%
#計算最近的火車站與火車站之間距離
def nearest_train_station(extra,train):
    nearest = []
    distance = []
    for i in range(len(train)):
        nearest_station = None
        min_distance = float("inf")

        for j in range(len(extra)):
            # compute distance
            d = compute_distance(extra['lng'][j],extra['lat'][j],train['橫坐標'][i],train['縱坐標'][i])
            if d < min_distance:
                min_distance = d
                nearest_station = extra['車站級別'][j]
        nearest.append(nearest_station)
        distance.append(min_distance)
    train['最近火車站'] = nearest
    train['最近火車站距離'] = distance
    return

# %%
#計算方圓一定距離內出現站點數量
def station_count(extra,train,target_distance,name):
    count = []
    for i in range(len(train)):
        station_count = 0
        for j in range(len(extra)):
            d = compute_distance(extra['lng'][j],extra['lat'][j],train['橫坐標'][i],train['縱坐標'][i])
            if d <= target_distance:
                station_count += 1
        count.append(station_count)
    train[name] = count
    return

# %%
nearest_train_station(train_extra,train_df)
nearest_train_station(train_extra,test_df)

# %%
tmp_train_df = train_df
tmp_test_df = test_df

tmp_train_df.to_csv('tmp_train_data.csv', index=False)
tmp_test_df.to_csv('tmp_test_data.csv', index=False)

# %%
#方圓800公尺內捷運站數量
station_count(mrt_extra,train_df,0.8,'捷運站數量')
station_count(mrt_extra,test_df,0.8,'捷運站數量')

# %%
tmp_train_df = train_df
tmp_test_df = test_df

tmp_train_df.to_csv('tmp_train_data.csv', index=False)
tmp_test_df.to_csv('tmp_test_data.csv', index=False)

# %%
#方圓300公尺內便利商店數量
station_count(con_extra,train_df,0.3,'便利商店數量')
station_count(con_extra,test_df,0.3,'便利商店數量')

# %%
tmp_train_df = train_df
tmp_test_df = test_df

tmp_train_df.to_csv('tmp_train_data.csv', index=False)
tmp_test_df.to_csv('tmp_test_data.csv', index=False)

# %%
#方圓300公尺內國小數量
station_count(ele_extra,train_df,0.3,'國小數量')
station_count(ele_extra,test_df,0.3,'國小數量')

# %%
tmp_train_df = train_df
tmp_test_df = test_df

tmp_train_df.to_csv('tmp_train_data.csv', index=False)
tmp_test_df.to_csv('tmp_test_data.csv', index=False)

# %%
#方圓800公尺內國中數量
station_count(jun_extra,train_df,0.8,'國中數量')
station_count(jun_extra,test_df,0.8,'國中數量')

# %%
tmp_train_df = train_df
tmp_test_df = test_df

tmp_train_df.to_csv('tmp_train_data.csv', index=False)
tmp_test_df.to_csv('tmp_test_data.csv', index=False)

# %%
train_df = pd.read_csv('tmp_train_data.csv')
test_df = pd.read_csv('tmp_test_data.csv')

# %%
#方圓1000公尺內高中數量
station_count(high_extra,train_df,1.0,'高中數量')
station_count(high_extra,test_df,1.0,'高中數量')

# %%
tmp_train_df = train_df
tmp_test_df = test_df

tmp_train_df.to_csv('tmp_train_data.csv', index=False)
tmp_test_df.to_csv('tmp_test_data.csv', index=False)

# %%
#方圓1000公尺內大學數量
station_count(uni_extra,train_df,1.0,'大學數量')
station_count(uni_extra,test_df,1.0,'大學數量')

# %%
tmp_train_df = train_df
tmp_test_df = test_df

tmp_train_df.to_csv('tmp_train_data.csv', index=False)
tmp_test_df.to_csv('tmp_test_data.csv', index=False)

# %%
#方圓1000公尺內金融機構數量
station_count(fin_extra,train_df,1.0,'金融機構數量')
station_count(fin_extra,test_df,1.0,'金融機構數量')

# %%
tmp_train_df = train_df
tmp_test_df = test_df

tmp_train_df.to_csv('tmp_train_data.csv', index=False)
tmp_test_df.to_csv('tmp_test_data.csv', index=False)

# %%
#方圓300公尺內醫院數量
station_count(hos_extra,train_df,0.3,'醫院數量')
station_count(hos_extra,test_df,0.3,'醫院數量')

# %%
tmp_train_df = train_df
tmp_test_df = test_df

tmp_train_df.to_csv('tmp_train_data.csv', index=False)
tmp_test_df.to_csv('tmp_test_data.csv', index=False)

# %%
train_df.describe()
# Out:
#                土地面積          移轉層次          總樓層數            屋齡          建物面積
# count  11751.000000  11751.000000  11751.000000  11751.000000  11751.000000  \
# mean       0.018416      7.433665     12.602672     21.319058      0.030517
# std        1.072279      5.089029      6.840007     14.425560      1.083602
# min       -1.619755      2.000000      2.000000      0.000000     -1.909259
# 25%       -0.646264      4.000000      7.000000      8.083333     -0.619995
# 50%       -0.149839      6.000000     12.000000     21.750000     -0.191390
# 75%        0.410167     10.000000     15.000000     31.250000      0.339483
# max       19.475175     46.000000     68.000000     60.083333     13.026437
#
#                車位面積          車位個數            橫坐標           縱坐標         主建物面積
# count  11751.000000  11751.000000   11751.000000  1.175100e+04  11751.000000  \
# mean       0.021030      0.638669  268260.431878  2.719114e+06      0.026623
# std        1.030720      0.678157   50065.477460  9.271248e+04      1.077374
# min       -0.819326      0.000000  -23391.000000  2.493809e+06     -2.070340
# 25%       -0.819326      0.000000  237588.500000  2.708082e+06     -0.612460
# 50%       -0.334257      1.000000  294675.000000  2.766329e+06     -0.148660
# 75%        0.677589      1.000000  302130.000000  2.772017e+06      0.395765
# max       14.007695      3.000000  334128.000000  2.790801e+06     12.099402
#
#        ...         最近火車站       最近火車站距離         捷運站數量        便利商店數量
# count  ...  11751.000000  11751.000000  11751.000000  11751.000000  \
# mean   ...      2.297592      3.946904      0.809123      5.054719
# std    ...      1.474848     11.474784      1.205408      3.474868
# min    ...      0.000000      0.014161      0.000000      0.000000
# 25%    ...      1.000000      1.390980      0.000000      3.000000
# 50%    ...      1.000000      2.510331      0.000000      4.000000
# 75%    ...      4.000000      4.386275      1.000000      7.000000
# max    ...      5.000000    228.461947      7.000000     28.000000
#
#                國小數量          國中數量          高中數量          大學數量        金融機構數量
# count  11751.000000  11751.000000  11751.000000  11751.000000  11751.000000  \
# mean       0.457833      1.168496      1.046039      1.161603     17.326355
# std        1.134408      1.136339      1.168454      2.637151     19.362722
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      5.000000
# 50%        0.000000      1.000000      1.000000      0.000000     12.000000
# 75%        1.000000      2.000000      2.000000      0.000000     22.000000
# max       10.000000      8.000000      7.000000     17.000000    133.000000
#
#                醫院數量
# count  11751.000000
# mean       9.945281
# std       11.089960
# min        0.000000
# 25%        2.000000
# 50%        7.000000
# 75%       15.000000
# max      126.000000
#
# [8 rows x 23 columns]

# %%
# 刪除outlier
# 土地面積
train_df = train_df.drop(train_df.loc[train_df['土地面積'] > 7.12].index, axis = 0)
train_df = train_df.drop(train_df.loc[train_df['土地面積'] < -1.65].index, axis = 0)

# 移轉層次
train_df = train_df.drop(train_df.loc[train_df['移轉層次'] > 35].index, axis = 0)

# 總樓層數
train_df = train_df.drop(train_df.loc[train_df['總樓層數'] > 41].index, axis = 0)

# 建物面積
train_df = train_df.drop(train_df.loc[train_df['建物面積'] > 6.02].index, axis = 0)
train_df = train_df.drop(train_df.loc[train_df['建物面積'] < -1.8].index, axis = 0)

# 車位面積
train_df = train_df.drop(train_df.loc[train_df['車位面積'] > 5.15].index, axis = 0)
train_df = train_df.drop(train_df.loc[train_df['車位面積'] < -0.82].index, axis = 0)

# 主建物面積
train_df = train_df.drop(train_df.loc[train_df['主建物面積'] > 5.85].index, axis = 0)
train_df = train_df.drop(train_df.loc[train_df['主建物面積'] < -2.03].index, axis = 0)

# 陽台面積
train_df = train_df.drop(train_df.loc[train_df['陽台面積'] > 4.9].index, axis = 0)
train_df = train_df.drop(train_df.loc[train_df['陽台面積'] < -1.65].index, axis = 0)

# 附屬建物面積
train_df = train_df.drop(train_df.loc[train_df['附屬建物面積'] > 13.31].index, axis = 0)
train_df = train_df.drop(train_df.loc[train_df['附屬建物面積'] < -0.44].index, axis = 0)

# %%
# 使用分區 {住:1, 商:2, 農:3, 工:4, 其他:0}
mapping = {'住':1, '商':2, '農':3, '工':4}
train_df['使用分區'] = train_df['使用分區'].map(mapping).fillna(0).astype(int)
test_df['使用分區'] = test_df['使用分區'].map(mapping).fillna(0).astype(int)

# 主要建材 {鋼筋混凝土造:1, 鋼骨造:2, 加強磚造:3, 其他:0}
mapping = {'鋼筋混凝土造':1, '鋼骨造':2, '加強磚造':3}
train_df['主要建材'] = train_df['主要建材'].map(mapping).fillna(0).astype(int)
test_df['主要建材'] = test_df['主要建材'].map(mapping).fillna(0).astype(int)

# 建物型態 {住宅大樓:1, 公寓 3:華廈 4:透天厝 0:其他}
mapping = {'住宅大樓(11層含以上有電梯)':1, '公寓(5樓含以下無電梯)':2, '華廈(10層含以下有電梯)':3, '透天厝':4}
train_df['建物型態'] = train_df['建物型態'].map(mapping).fillna(0).astype(int)
test_df['建物型態'] = test_df['建物型態'].map(mapping).fillna(0).astype(int)

# 主要用途 {住家用:1, 集合住宅:2, 商業用:3, 一般事務所:4, 國民住宅:5, 住商用:6, 工業用:7, 辦公室:8, 住工用:9, 店鋪:10, 廠房:11, 其他:0}
mapping = {'住家用':1, '集合住宅':2, '商業用':3, '一般事務所':4, '國民住宅':5, '住商用':6, '工業用':7, '辦公室':8, '住工用':9, '店鋪':10, '廠房':11, '其他':0}
train_df['主要用途'] = train_df['主要用途'].map(mapping).fillna(0).astype(int)
test_df['主要用途'] = test_df['主要用途'].map(mapping).fillna(0).astype(int)

# %%
def map_city_area(row,city,mapping):
    if row['縣市'] == city:
        return mapping.get(row['鄉鎮市區'], 0)
    else:
        return -1

# 六都區域mapping

# 台北市 （其他: 0, 別的縣市: -1）
mapping = {'大安區': 1, '中山區': 2, '內湖區': 3, '信義區': 4, '士林區': 5, '文山區': 6, '松山區': 7,
           '北投區': 8, '中正區': 9, '萬華區': 10, '大同區': 11, '南港區': 12}
train_df['台北市區'] = train_df.apply(map_city_area, args=('台北市', mapping), axis=1)
test_df['台北市區'] = test_df.apply(map_city_area, args=('台北市', mapping), axis=1)

# 新北市
mapping = {'板橋區': 1, '新莊區': 2, '中和區': 3, '三重區': 4, '汐止區': 5, '新店區': 6, '土城區': 7,
           '林口區': 8, '永和區': 9, '淡水區': 10, '蘆洲區': 11, '五股區': 12, '樹林區': 13, '三峽區': 14, '鶯歌區': 15,
           '泰山區':16, '深坑區':17, '八里區':18}
train_df['新北市區'] = train_df.apply(map_city_area, args=('新北市', mapping), axis=1)
test_df['新北市區'] = test_df.apply(map_city_area, args=('新北市', mapping), axis=1)

# 桃園市
mapping = {'桃園區': 1, '中壢區': 2, '蘆竹區': 3, '八德區': 4, '龜山區': 5, '平鎮區': 6, '楊梅區': 7,
           '大園區': 8, '大溪區': 9, '龍潭區': 10, '觀音區': 11}
train_df['桃園市區'] = train_df.apply(map_city_area, args=('桃園市', mapping), axis=1)
test_df['桃園市區'] = test_df.apply(map_city_area, args=('桃園市', mapping), axis=1)

# 台中市
mapping = {'西屯區': 1, '北屯區': 2, '南屯區': 3, '南區': 4, '西區': 5, '北區': 6, '太平區': 7,
           '大里區': 8, '潭子區': 9, '烏日區': 10, '東區': 11, '豐原區': 12, '神岡區': 13, '大雅區': 14, '中區': 15}
train_df['台中市區'] = train_df.apply(map_city_area, args=('台中市', mapping), axis=1)
test_df['台中市區'] = test_df.apply(map_city_area, args=('台中市', mapping), axis=1)


# 台南市
mapping = {'永康區': 1, '安平區': 2, '北區': 3, '東區': 4, '中西區': 5, '南區': 6, '安南區': 7,
           '仁德區': 8, '善化區': 9, '新市區': 10, '新營區': 11}
train_df['台南市區'] = train_df.apply(map_city_area, args=('台南市', mapping), axis=1)
test_df['台南市區'] = test_df.apply(map_city_area, args=('台南市', mapping), axis=1)

# 高雄市
mapping = {'鼓山區': 1, '三民區': 2, '左營區': 3, '楠梓區': 4, '鳳山區': 5, '零雅區': 6, '前鎮區': 7,
           '前金區': 8, '新興區': 9, '仁武區': 10, '小港區': 11, '橋頭區':12, '鹽埕區':13, '岡山區':14, '鳥松區':15}
train_df['高雄市區'] = train_df.apply(map_city_area, args=('高雄市', mapping), axis=1)
test_df['高雄市區'] = test_df.apply(map_city_area, args=('高雄市', mapping), axis=1)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11595 entries, 0 to 11750
# Data columns (total 38 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       11595 non-null  object
#  1   縣市       11595 non-null  object
#  2   鄉鎮市區     11595 non-null  object
#  3   路名       11595 non-null  object
#  4   土地面積     11595 non-null  float64
#  5   使用分區     11595 non-null  int64
#  6   移轉層次     11595 non-null  int64
#  7   總樓層數     11595 non-null  int64
#  8   主要用途     11595 non-null  int64
#  9   主要建材     11595 non-null  int64
#  10  建物型態     11595 non-null  int64
#  11  屋齡       11595 non-null  float64
#  12  建物面積     11595 non-null  float64
#  13  車位面積     11595 non-null  float64
#  14  車位個數     11595 non-null  float64
#  15  橫坐標      11595 non-null  int64
#  16  縱坐標      11595 non-null  int64
#  17  備註       88 non-null     object
#  18  主建物面積    11595 non-null  float64
#  19  陽台面積     11595 non-null  float64
#  20  附屬建物面積   11595 non-null  float64
#  21  單價       11595 non-null  float64
#  22  最近火車站    11595 non-null  int64
#  23  最近火車站距離  11595 non-null  float64
#  24  捷運站數量    11595 non-null  int64
#  25  便利商店數量   11595 non-null  int64
#  26  國小數量     11595 non-null  int64
#  27  國中數量     11595 non-null  int64
#  28  高中數量     11595 non-null  int64
#  29  大學數量     11595 non-null  int64
#  30  金融機構數量   11595 non-null  int64
#  31  醫院數量     11595 non-null  int64
#  32  台北市區     11595 non-null  int64
#  33  新北市區     11595 non-null  int64
#  34  桃園市區     11595 non-null  int64
#  35  台中市區     11595 non-null  int64
#  36  台南市區     11595 non-null  int64
#  37  高雄市區     11595 non-null  int64
# dtypes: float64(10), int64(23), object(5)
# memory usage: 3.5+ MB

# %%
# New features
train_df['建物佔地比'] = (train_df['建物面積']/train_df['土地面積']).round(5)
train_df['樓高比']=(train_df['移轉層次']/train_df['總樓層數'])

test_df['建物佔地比'] = (test_df['建物面積']/test_df['土地面積']).round(5)
test_df['樓高比']=(test_df['移轉層次']/test_df['總樓層數'])

# %%
# 取到小數點後2位
train_df['屋齡'] = train_df['屋齡'].round(2).astype('float32')

# 取到小數點後5位
train_df['土地面積'] = train_df['土地面積'].round(5).astype('float32')
train_df['建物面積'] = train_df['建物面積'].round(5).astype('float32')
train_df['車位面積'] = train_df['車位面積'].round(5).astype('float32')
train_df['主建物面積'] = train_df['主建物面積'].round(5).astype('float32')
train_df['陽台面積'] = train_df['陽台面積'].round(5).astype('float32')
train_df['附屬建物面積'] = train_df['附屬建物面積'].round(5).astype('float32')

# %%
# 縣市 mapping
mapping = {'基隆市':1, '台北市':2, '新北市':3, '桃園市':4, '新竹市':5, '新竹縣':6, '苗栗縣':7,
           '台中市':8, '彰化縣':9, '南投縣':10, '雲林縣':11, '嘉義市':12, '嘉義縣':13, '台南市':14,
           '高雄市':15, '屏東縣':16, '台東縣':17, '花蓮縣':18, '宜蘭縣':19, '澎湖縣':20, '金門縣': 21, '連江縣':22}
train_df['縣市'] = train_df['縣市'].map(mapping).fillna(0).astype(int)
test_df['縣市'] = test_df['縣市'].map(mapping).fillna(0).astype(int)

# %%
# dropoff
train_df.drop(columns=['ID'],inplace=True)
train_df.drop(columns=['鄉鎮市區'],inplace=True)
train_df.drop(columns=['路名'],inplace=True)
train_df.drop(columns=['備註'],inplace=True)

test_df.drop(columns=['ID'],inplace=True)
test_df.drop(columns=['鄉鎮市區'],inplace=True)
test_df.drop(columns=['路名'],inplace=True)
test_df.drop(columns=['備註'],inplace=True)

# %%
X = train_df.iloc[:,train_df.columns != '單價']
Y = train_df['單價']
X.shape
# Out:
# (11595, 35)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=42, shuffle=True)

# %%
# XGBoost
params = {
    'max_depth': 10,
    'n_estimators':5000,
    'gamma' :0.003,
    'eta':.025,
    'subsample': 0.9,
    'colsample_bytree': 0.7,
    'objective':'reg:linear',
    'eval_metric':'mape',
    'silent': 0,
    'verbosity' : 0,
    'random_state' : 42,
}

def XGBmodel(X_train,X_valid,y_train,y_valid,params):
    matrix_train = xgb.DMatrix(X_train,label=y_train)
    matrix_valid = xgb.DMatrix(X_valid,label=y_valid)
    model=xgb.train(params=params,
                    dtrain=matrix_train,num_boost_round=10000,
                    early_stopping_rounds=500,evals=[(matrix_valid,'valid')])
    return model

xgbmodel = XGBmodel(X_train,X_valid,y_train,y_valid,params)
# Out:
# [0]	valid-mape:0.68240
# [1]	valid-mape:0.66525
# [2]	valid-mape:0.64863
# [3]	valid-mape:0.63223
# [4]	valid-mape:0.61645
# [5]	valid-mape:0.60089
# [6]	valid-mape:0.58574
# [7]	valid-mape:0.57117
# [8]	valid-mape:0.55677
# [9]	valid-mape:0.54283
# [10]	valid-mape:0.52918
# [11]	valid-mape:0.51594
# [12]	valid-mape:0.50267
# [13]	valid-mape:0.48998
# [14]	valid-mape:0.47764
# [15]	valid-mape:0.46572
# [16]	valid-mape:0.45401
# [17]	valid-mape:0.44273
# [18]	valid-mape:0.43156
# [19]	valid-mape:0.42075
# [20]	valid-mape:0.41021
# [21]	valid-mape:0.39991
# [22]	valid-mape:0.38994
# [23]	valid-mape:0.38012
# [24]	valid-mape:0.37068
# [25]	valid-mape:0.36139
# [26]	valid-mape:0.35233
# [27]	valid-mape:0.34357
# [28]	valid-mape:0.33498
# [29]	valid-mape:0.32682
# [30]	valid-mape:0.31874
# [31]	valid-mape:0.31088
# [32]	valid-mape:0.30323
# [33]	valid-mape:0.29580
# [34]	valid-mape:0.28864
# [35]	valid-mape:0.28163
# [36]	valid-mape:0.27482
# [37]	valid-mape:0.26816
# [38]	valid-mape:0.26170
# [39]	valid-mape:0.25544
# [40]	valid-mape:0.24939
# [41]	valid-mape:0.24343
# [42]	valid-mape:0.23772
# [43]	valid-mape:0.23217
# [44]	valid-mape:0.22683
# [45]	valid-mape:0.22160
# [46]	valid-mape:0.21647
# [47]	valid-mape:0.21160
# [48]	valid-mape:0.20677
# [49]	valid-mape:0.20215
# [50]	valid-mape:0.19764
# [51]	valid-mape:0.19325
# [52]	valid-mape:0.18911
# [53]	valid-mape:0.18506
# [54]	valid-mape:0.18114
# [55]	valid-mape:0.17734
# [56]	valid-mape:0.17364
# [57]	valid-mape:0.17004
# [58]	valid-mape:0.16663
# [59]	valid-mape:0.16335
# [60]	valid-mape:0.16020
# [61]	valid-mape:0.15712
# [62]	valid-mape:0.15415
# [63]	valid-mape:0.15129
# [64]	valid-mape:0.14850
# [65]	valid-mape:0.14587
# [66]	valid-mape:0.14331
# [67]	valid-mape:0.14080
# [68]	valid-mape:0.13848
# [69]	valid-mape:0.13623
# [70]	valid-mape:0.13401
# [71]	valid-mape:0.13190
# [72]	valid-mape:0.12988
# [73]	valid-mape:0.12795
# [74]	valid-mape:0.12604
# [75]	valid-mape:0.12428
# [76]	valid-mape:0.12260
# [77]	valid-mape:0.12099
# [78]	valid-mape:0.11939
# [79]	valid-mape:0.11792
# [80]	valid-mape:0.11649
# [81]	valid-mape:0.11511
# [82]	valid-mape:0.11383
# [83]	valid-mape:0.11259
# [84]	valid-mape:0.11142
# [85]	valid-mape:0.11035
# [86]	valid-mape:0.10929
# [87]	valid-mape:0.10825
# [88]	valid-mape:0.10729
# [89]	valid-mape:0.10633
# [90]	valid-mape:0.10544
# [91]	valid-mape:0.10455
# [92]	valid-mape:0.10371
# [93]	valid-mape:0.10289
# [94]	valid-mape:0.10216
# [95]	valid-mape:0.10145
# [96]	valid-mape:0.10080
# [97]	valid-mape:0.10016
# [98]	valid-mape:0.09948
# [99]	valid-mape:0.09885
# [100]	valid-mape:0.09828
# [101]	valid-mape:0.09774
# [102]	valid-mape:0.09718
# [103]	valid-mape:0.09667
# [104]	valid-mape:0.09616
# [105]	valid-mape:0.09568
# [106]	valid-mape:0.09523
# [107]	valid-mape:0.09480
# [108]	valid-mape:0.09442
# [109]	valid-mape:0.09404
# [110]	valid-mape:0.09374
# [111]	valid-mape:0.09342
# [112]	valid-mape:0.09308
# [113]	valid-mape:0.09276
# [114]	valid-mape:0.09247
# [115]	valid-mape:0.09221
# [116]	valid-mape:0.09196
# [117]	valid-mape:0.09171
# [118]	valid-mape:0.09149
# [119]	valid-mape:0.09130
# [120]	valid-mape:0.09110
# [121]	valid-mape:0.09088
# [122]	valid-mape:0.09073
# [123]	valid-mape:0.09054
# [124]	valid-mape:0.09036
# [125]	valid-mape:0.09018
# [126]	valid-mape:0.09002
# [127]	valid-mape:0.08987
# [128]	valid-mape:0.08974
# [129]	valid-mape:0.08961
# [130]	valid-mape:0.08949
# [131]	valid-mape:0.08938
# [132]	valid-mape:0.08929
# [133]	valid-mape:0.08918
# [134]	valid-mape:0.08908
# [135]	valid-mape:0.08901
# [136]	valid-mape:0.08889
# [137]	valid-mape:0.08883
# [138]	valid-mape:0.08876
# [139]	valid-mape:0.08868
# [140]	valid-mape:0.08860
# [141]	valid-mape:0.08849
# [142]	valid-mape:0.08841
# [143]	valid-mape:0.08836
# [144]	valid-mape:0.08828
# [145]	valid-mape:0.08823
# [146]	valid-mape:0.08818
# [147]	valid-mape:0.08815
# [148]	valid-mape:0.08808
# [149]	valid-mape:0.08803
# [150]	valid-mape:0.08797
# [151]	valid-mape:0.08793
# [152]	valid-mape:0.08788
# [153]	valid-mape:0.08786
# [154]	valid-mape:0.08784
# [155]	valid-mape:0.08781
# [156]	valid-mape:0.08777
# [157]	valid-mape:0.08776
# [158]	valid-mape:0.08774
# [159]	valid-mape:0.08769
# [160]	valid-mape:0.08765
# [161]	valid-mape:0.08761
# [162]	valid-mape:0.08759
# [163]	valid-mape:0.08758
# [164]	valid-mape:0.08754
# [165]	valid-mape:0.08754
# [166]	valid-mape:0.08750
# [167]	valid-mape:0.08750
# [168]	valid-mape:0.08747
# [169]	valid-mape:0.08747
# [170]	valid-mape:0.08745
# [171]	valid-mape:0.08741
# [172]	valid-mape:0.08740
# [173]	valid-mape:0.08739
# [174]	valid-mape:0.08738
# [175]	valid-mape:0.08737
# [176]	valid-mape:0.08736
# [177]	valid-mape:0.08734
# [178]	valid-mape:0.08732
# [179]	valid-mape:0.08732
# [180]	valid-mape:0.08727
# [181]	valid-mape:0.08726
# [182]	valid-mape:0.08725
# [183]	valid-mape:0.08721
# [184]	valid-mape:0.08722
# [185]	valid-mape:0.08722
# [186]	valid-mape:0.08721
# [187]	valid-mape:0.08718
# [188]	valid-mape:0.08718
# [189]	valid-mape:0.08718
# [190]	valid-mape:0.08717
# [191]	valid-mape:0.08717
# [192]	valid-mape:0.08717
# [193]	valid-mape:0.08717
# [194]	valid-mape:0.08714
# [195]	valid-mape:0.08714
# [196]	valid-mape:0.08715
# [197]	valid-mape:0.08715
# [198]	valid-mape:0.08716
# [199]	valid-mape:0.08716
# [200]	valid-mape:0.08717
# [201]	valid-mape:0.08717
# [202]	valid-mape:0.08716
# [203]	valid-mape:0.08715
# [204]	valid-mape:0.08714
# [205]	valid-mape:0.08715
# [206]	valid-mape:0.08716
# [207]	valid-mape:0.08715
# [208]	valid-mape:0.08714
# [209]	valid-mape:0.08715
# [210]	valid-mape:0.08714
# [211]	valid-mape:0.08712
# [212]	valid-mape:0.08712
# [213]	valid-mape:0.08712
# [214]	valid-mape:0.08710
# [215]	valid-mape:0.08711
# [216]	valid-mape:0.08710
# [217]	valid-mape:0.08711
# [218]	valid-mape:0.08712
# [219]	valid-mape:0.08713
# [220]	valid-mape:0.08710
# [221]	valid-mape:0.08708
# [222]	valid-mape:0.08707
# [223]	valid-mape:0.08706
# [224]	valid-mape:0.08706
# [225]	valid-mape:0.08702
# [226]	valid-mape:0.08702
# [227]	valid-mape:0.08700
# [228]	valid-mape:0.08700
# [229]	valid-mape:0.08699
# [230]	valid-mape:0.08700
# [231]	valid-mape:0.08699
# [232]	valid-mape:0.08699
# [233]	valid-mape:0.08697
# [234]	valid-mape:0.08696
# [235]	valid-mape:0.08694
# [236]	valid-mape:0.08695
# [237]	valid-mape:0.08694
# [238]	valid-mape:0.08693
# [239]	valid-mape:0.08693
# [240]	valid-mape:0.08692
# [241]	valid-mape:0.08689
# [242]	valid-mape:0.08690
# [243]	valid-mape:0.08689
# [244]	valid-mape:0.08688
# [245]	valid-mape:0.08686
# [246]	valid-mape:0.08687
# [247]	valid-mape:0.08687
# [248]	valid-mape:0.08687
# [249]	valid-mape:0.08686
# [250]	valid-mape:0.08687
# [251]	valid-mape:0.08685
# [252]	valid-mape:0.08685
# [253]	valid-mape:0.08682
# [254]	valid-mape:0.08682
# [255]	valid-mape:0.08680
# [256]	valid-mape:0.08677
# [257]	valid-mape:0.08677
# [258]	valid-mape:0.08676
# [259]	valid-mape:0.08674
# [260]	valid-mape:0.08673
# [261]	valid-mape:0.08673
# [262]	valid-mape:0.08672
# [263]	valid-mape:0.08671
# [264]	valid-mape:0.08670
# [265]	valid-mape:0.08670
# [266]	valid-mape:0.08669
# [267]	valid-mape:0.08668
# [268]	valid-mape:0.08669
# [269]	valid-mape:0.08669
# [270]	valid-mape:0.08669
# [271]	valid-mape:0.08669
# [272]	valid-mape:0.08668
# [273]	valid-mape:0.08667
# [274]	valid-mape:0.08665
# [275]	valid-mape:0.08665
# [276]	valid-mape:0.08664
# [277]	valid-mape:0.08662
# [278]	valid-mape:0.08664
# [279]	valid-mape:0.08663
# [280]	valid-mape:0.08663
# [281]	valid-mape:0.08663
# [282]	valid-mape:0.08662
# [283]	valid-mape:0.08661
# [284]	valid-mape:0.08661
# [285]	valid-mape:0.08660
# [286]	valid-mape:0.08661
# [287]	valid-mape:0.08661
# [288]	valid-mape:0.08660
# [289]	valid-mape:0.08659
# [290]	valid-mape:0.08660
# [291]	valid-mape:0.08660
# [292]	valid-mape:0.08660
# [293]	valid-mape:0.08660
# [294]	valid-mape:0.08659
# [295]	valid-mape:0.08658
# [296]	valid-mape:0.08658
# [297]	valid-mape:0.08658
# [298]	valid-mape:0.08656
# [299]	valid-mape:0.08655
# [300]	valid-mape:0.08655
# [301]	valid-mape:0.08653
# [302]	valid-mape:0.08652
# [303]	valid-mape:0.08652
# [304]	valid-mape:0.08650
# [305]	valid-mape:0.08651
# [306]	valid-mape:0.08648
# [307]	valid-mape:0.08647
# [308]	valid-mape:0.08649
# [309]	valid-mape:0.08649
# [310]	valid-mape:0.08648
# [311]	valid-mape:0.08646
# [312]	valid-mape:0.08646
# [313]	valid-mape:0.08647
# [314]	valid-mape:0.08647
# [315]	valid-mape:0.08646
# [316]	valid-mape:0.08646
# [317]	valid-mape:0.08647
# [318]	valid-mape:0.08644
# [319]	valid-mape:0.08644
# [320]	valid-mape:0.08645
# [321]	valid-mape:0.08644
# [322]	valid-mape:0.08644
# [323]	valid-mape:0.08643
# [324]	valid-mape:0.08644
# [325]	valid-mape:0.08643
# [326]	valid-mape:0.08643
# [327]	valid-mape:0.08642
# [328]	valid-mape:0.08641
# [329]	valid-mape:0.08641
# [330]	valid-mape:0.08640
# [331]	valid-mape:0.08638
# [332]	valid-mape:0.08638
# [333]	valid-mape:0.08638
# [334]	valid-mape:0.08639
# [335]	valid-mape:0.08638
# [336]	valid-mape:0.08638
# [337]	valid-mape:0.08637
# [338]	valid-mape:0.08637
# [339]	valid-mape:0.08637
# [340]	valid-mape:0.08637
# [341]	valid-mape:0.08636
# [342]	valid-mape:0.08635
# [343]	valid-mape:0.08635
# [344]	valid-mape:0.08634
# [345]	valid-mape:0.08635
# [346]	valid-mape:0.08635
# [347]	valid-mape:0.08634
# [348]	valid-mape:0.08633
# [349]	valid-mape:0.08634
# [350]	valid-mape:0.08633
# [351]	valid-mape:0.08633
# [352]	valid-mape:0.08633
# [353]	valid-mape:0.08632
# [354]	valid-mape:0.08633
# [355]	valid-mape:0.08633
# [356]	valid-mape:0.08633
# [357]	valid-mape:0.08632
# [358]	valid-mape:0.08632
# [359]	valid-mape:0.08632
# [360]	valid-mape:0.08632
# [361]	valid-mape:0.08631
# [362]	valid-mape:0.08631
# [363]	valid-mape:0.08631
# [364]	valid-mape:0.08630
# [365]	valid-mape:0.08629
# [366]	valid-mape:0.08628
# [367]	valid-mape:0.08627
# [368]	valid-mape:0.08628
# [369]	valid-mape:0.08628
# [370]	valid-mape:0.08628
# [371]	valid-mape:0.08628
# [372]	valid-mape:0.08627
# [373]	valid-mape:0.08627
# [374]	valid-mape:0.08626
# [375]	valid-mape:0.08626
# [376]	valid-mape:0.08626
# [377]	valid-mape:0.08626
# [378]	valid-mape:0.08627
# [379]	valid-mape:0.08626
# [380]	valid-mape:0.08626
# [381]	valid-mape:0.08626
# [382]	valid-mape:0.08626
# [383]	valid-mape:0.08625
# [384]	valid-mape:0.08626
# [385]	valid-mape:0.08625
# [386]	valid-mape:0.08626
# [387]	valid-mape:0.08625
# [388]	valid-mape:0.08625
# [389]	valid-mape:0.08625
# [390]	valid-mape:0.08624
# [391]	valid-mape:0.08624
# [392]	valid-mape:0.08624
# [393]	valid-mape:0.08625
# [394]	valid-mape:0.08625
# [395]	valid-mape:0.08625
# [396]	valid-mape:0.08625
# [397]	valid-mape:0.08624
# [398]	valid-mape:0.08624
# [399]	valid-mape:0.08624
# [400]	valid-mape:0.08623
# [401]	valid-mape:0.08622
# [402]	valid-mape:0.08621
# [403]	valid-mape:0.08621
# [404]	valid-mape:0.08620
# [405]	valid-mape:0.08620
# [406]	valid-mape:0.08620
# [407]	valid-mape:0.08621
# [408]	valid-mape:0.08621
# [409]	valid-mape:0.08621
# [410]	valid-mape:0.08620
# [411]	valid-mape:0.08620
# [412]	valid-mape:0.08619
# [413]	valid-mape:0.08619
# [414]	valid-mape:0.08620
# [415]	valid-mape:0.08620
# [416]	valid-mape:0.08620
# [417]	valid-mape:0.08619
# [418]	valid-mape:0.08619
# [419]	valid-mape:0.08619
# [420]	valid-mape:0.08619
# [421]	valid-mape:0.08618
# [422]	valid-mape:0.08619
# [423]	valid-mape:0.08617
# [424]	valid-mape:0.08616
# [425]	valid-mape:0.08616
# [426]	valid-mape:0.08615
# [427]	valid-mape:0.08614
# [428]	valid-mape:0.08613
# [429]	valid-mape:0.08612
# [430]	valid-mape:0.08613
# [431]	valid-mape:0.08613
# [432]	valid-mape:0.08613
# [433]	valid-mape:0.08613
# [434]	valid-mape:0.08613
# [435]	valid-mape:0.08614
# [436]	valid-mape:0.08613
# [437]	valid-mape:0.08613
# [438]	valid-mape:0.08613
# [439]	valid-mape:0.08614
# [440]	valid-mape:0.08614
# [441]	valid-mape:0.08614
# [442]	valid-mape:0.08614
# [443]	valid-mape:0.08613
# [444]	valid-mape:0.08613
# [445]	valid-mape:0.08612
# [446]	valid-mape:0.08611
# [447]	valid-mape:0.08611
# [448]	valid-mape:0.08610
# [449]	valid-mape:0.08609
# [450]	valid-mape:0.08609
# [451]	valid-mape:0.08609
# [452]	valid-mape:0.08609
# [453]	valid-mape:0.08609
# [454]	valid-mape:0.08609
# [455]	valid-mape:0.08609
# [456]	valid-mape:0.08608
# [457]	valid-mape:0.08608
# [458]	valid-mape:0.08608
# [459]	valid-mape:0.08606
# [460]	valid-mape:0.08606
# [461]	valid-mape:0.08606
# [462]	valid-mape:0.08605
# [463]	valid-mape:0.08605
# [464]	valid-mape:0.08605
# [465]	valid-mape:0.08605
# [466]	valid-mape:0.08605
# [467]	valid-mape:0.08605
# [468]	valid-mape:0.08604
# [469]	valid-mape:0.08604
# [470]	valid-mape:0.08604
# [471]	valid-mape:0.08603
# [472]	valid-mape:0.08603
# [473]	valid-mape:0.08603
# [474]	valid-mape:0.08603
# [475]	valid-mape:0.08603
# [476]	valid-mape:0.08603
# [477]	valid-mape:0.08604
# [478]	valid-mape:0.08604
# [479]	valid-mape:0.08604
# [480]	valid-mape:0.08605
# [481]	valid-mape:0.08605
# [482]	valid-mape:0.08604
# [483]	valid-mape:0.08604
# [484]	valid-mape:0.08604
# [485]	valid-mape:0.08605
# [486]	valid-mape:0.08604
# [487]	valid-mape:0.08604
# [488]	valid-mape:0.08603
# [489]	valid-mape:0.08603
# [490]	valid-mape:0.08603
# [491]	valid-mape:0.08602
# [492]	valid-mape:0.08601
# [493]	valid-mape:0.08601
# [494]	valid-mape:0.08601
# [495]	valid-mape:0.08601
# [496]	valid-mape:0.08601
# [497]	valid-mape:0.08601
# [498]	valid-mape:0.08601
# [499]	valid-mape:0.08601
# [500]	valid-mape:0.08602
# [501]	valid-mape:0.08602
# [502]	valid-mape:0.08602
# [503]	valid-mape:0.08602
# [504]	valid-mape:0.08603
# [505]	valid-mape:0.08601
# [506]	valid-mape:0.08601
# [507]	valid-mape:0.08600
# [508]	valid-mape:0.08600
# [509]	valid-mape:0.08600
# [510]	valid-mape:0.08599
# [511]	valid-mape:0.08599
# [512]	valid-mape:0.08600
# [513]	valid-mape:0.08599
# [514]	valid-mape:0.08600
# [515]	valid-mape:0.08599
# [516]	valid-mape:0.08599
# [517]	valid-mape:0.08599
# [518]	valid-mape:0.08599
# [519]	valid-mape:0.08598
# [520]	valid-mape:0.08598
# [521]	valid-mape:0.08598
# [522]	valid-mape:0.08598
# [523]	valid-mape:0.08598
# [524]	valid-mape:0.08598
# [525]	valid-mape:0.08598
# [526]	valid-mape:0.08598
# [527]	valid-mape:0.08598
# [528]	valid-mape:0.08598
# [529]	valid-mape:0.08598
# [530]	valid-mape:0.08598
# [531]	valid-mape:0.08597
# [532]	valid-mape:0.08597
# [533]	valid-mape:0.08596
# [534]	valid-mape:0.08596
# [535]	valid-mape:0.08595
# [536]	valid-mape:0.08595
# [537]	valid-mape:0.08595
# [538]	valid-mape:0.08595
# [539]	valid-mape:0.08595
# [540]	valid-mape:0.08594
# [541]	valid-mape:0.08594
# [542]	valid-mape:0.08595
# [543]	valid-mape:0.08594
# [544]	valid-mape:0.08595
# [545]	valid-mape:0.08595
# [546]	valid-mape:0.08595
# [547]	valid-mape:0.08595
# [548]	valid-mape:0.08594
# [549]	valid-mape:0.08595
# [550]	valid-mape:0.08594
# [551]	valid-mape:0.08594
# [552]	valid-mape:0.08594
# [553]	valid-mape:0.08593
# [554]	valid-mape:0.08593
# [555]	valid-mape:0.08593
# [556]	valid-mape:0.08594
# [557]	valid-mape:0.08595
# [558]	valid-mape:0.08594
# [559]	valid-mape:0.08594
# [560]	valid-mape:0.08594
# [561]	valid-mape:0.08594
# [562]	valid-mape:0.08594
# [563]	valid-mape:0.08594
# [564]	valid-mape:0.08594
# [565]	valid-mape:0.08594
# [566]	valid-mape:0.08594
# [567]	valid-mape:0.08594
# [568]	valid-mape:0.08594
# [569]	valid-mape:0.08594
# [570]	valid-mape:0.08593
# [571]	valid-mape:0.08593
# [572]	valid-mape:0.08593
# [573]	valid-mape:0.08593
# [574]	valid-mape:0.08593
# [575]	valid-mape:0.08593
# [576]	valid-mape:0.08592
# [577]	valid-mape:0.08592
# [578]	valid-mape:0.08592
# [579]	valid-mape:0.08592
# [580]	valid-mape:0.08591
# [581]	valid-mape:0.08592
# [582]	valid-mape:0.08592
# [583]	valid-mape:0.08591
# [584]	valid-mape:0.08591
# [585]	valid-mape:0.08591
# [586]	valid-mape:0.08591
# [587]	valid-mape:0.08591
# [588]	valid-mape:0.08592
# [589]	valid-mape:0.08591
# [590]	valid-mape:0.08591
# [591]	valid-mape:0.08591
# [592]	valid-mape:0.08590
# [593]	valid-mape:0.08590
# [594]	valid-mape:0.08590
# [595]	valid-mape:0.08590
# [596]	valid-mape:0.08590
# [597]	valid-mape:0.08590
# [598]	valid-mape:0.08590
# [599]	valid-mape:0.08591
# [600]	valid-mape:0.08591
# [601]	valid-mape:0.08590
# [602]	valid-mape:0.08590
# [603]	valid-mape:0.08590
# [604]	valid-mape:0.08589
# [605]	valid-mape:0.08590
# [606]	valid-mape:0.08590
# [607]	valid-mape:0.08590
# [608]	valid-mape:0.08589
# [609]	valid-mape:0.08589
# [610]	valid-mape:0.08588
# [611]	valid-mape:0.08588
# [612]	valid-mape:0.08588
# [613]	valid-mape:0.08588
# [614]	valid-mape:0.08588
# [615]	valid-mape:0.08588
# [616]	valid-mape:0.08588
# [617]	valid-mape:0.08588
# [618]	valid-mape:0.08588
# [619]	valid-mape:0.08588
# [620]	valid-mape:0.08588
# [621]	valid-mape:0.08587
# [622]	valid-mape:0.08587
# [623]	valid-mape:0.08587
# [624]	valid-mape:0.08587
# [625]	valid-mape:0.08587
# [626]	valid-mape:0.08586
# [627]	valid-mape:0.08586
# [628]	valid-mape:0.08586
# [629]	valid-mape:0.08585
# [630]	valid-mape:0.08584
# [631]	valid-mape:0.08584
# [632]	valid-mape:0.08584
# [633]	valid-mape:0.08585
# [634]	valid-mape:0.08585
# [635]	valid-mape:0.08585
# [636]	valid-mape:0.08585
# [637]	valid-mape:0.08585
# [638]	valid-mape:0.08585
# [639]	valid-mape:0.08584
# [640]	valid-mape:0.08584
# [641]	valid-mape:0.08583
# [642]	valid-mape:0.08583
# [643]	valid-mape:0.08583
# [644]	valid-mape:0.08583
# [645]	valid-mape:0.08583
# [646]	valid-mape:0.08583
# [647]	valid-mape:0.08582
# [648]	valid-mape:0.08582
# [649]	valid-mape:0.08582
# [650]	valid-mape:0.08583
# [651]	valid-mape:0.08583
# [652]	valid-mape:0.08583
# [653]	valid-mape:0.08583
# [654]	valid-mape:0.08582
# [655]	valid-mape:0.08582
# [656]	valid-mape:0.08582
# [657]	valid-mape:0.08582
# [658]	valid-mape:0.08582
# [659]	valid-mape:0.08582
# [660]	valid-mape:0.08582
# [661]	valid-mape:0.08581
# [662]	valid-mape:0.08582
# [663]	valid-mape:0.08581
# [664]	valid-mape:0.08581
# [665]	valid-mape:0.08581
# [666]	valid-mape:0.08581
# [667]	valid-mape:0.08581
# [668]	valid-mape:0.08581
# [669]	valid-mape:0.08581
# [670]	valid-mape:0.08581
# [671]	valid-mape:0.08581
# [672]	valid-mape:0.08582
# [673]	valid-mape:0.08582
# [674]	valid-mape:0.08582
# [675]	valid-mape:0.08582
# [676]	valid-mape:0.08580
# [677]	valid-mape:0.08580
# [678]	valid-mape:0.08581
# [679]	valid-mape:0.08581
# [680]	valid-mape:0.08580
# [681]	valid-mape:0.08581
# [682]	valid-mape:0.08580
# [683]	valid-mape:0.08581
# [684]	valid-mape:0.08581
# [685]	valid-mape:0.08580
# [686]	valid-mape:0.08580
# [687]	valid-mape:0.08580
# [688]	valid-mape:0.08580
# [689]	valid-mape:0.08580
# [690]	valid-mape:0.08580
# [691]	valid-mape:0.08580
# [692]	valid-mape:0.08579
# [693]	valid-mape:0.08580
# [694]	valid-mape:0.08580
# [695]	valid-mape:0.08579
# [696]	valid-mape:0.08579
# [697]	valid-mape:0.08579
# [698]	valid-mape:0.08579
# [699]	valid-mape:0.08579
# [700]	valid-mape:0.08580
# [701]	valid-mape:0.08580
# [702]	valid-mape:0.08580
# [703]	valid-mape:0.08580
# [704]	valid-mape:0.08580
# [705]	valid-mape:0.08581
# [706]	valid-mape:0.08580
# [707]	valid-mape:0.08580
# [708]	valid-mape:0.08580
# [709]	valid-mape:0.08580
# [710]	valid-mape:0.08580
# [711]	valid-mape:0.08580
# [712]	valid-mape:0.08581
# [713]	valid-mape:0.08580
# [714]	valid-mape:0.08581
# [715]	valid-mape:0.08581
# [716]	valid-mape:0.08581
# [717]	valid-mape:0.08581
# [718]	valid-mape:0.08581
# [719]	valid-mape:0.08581
# [720]	valid-mape:0.08581
# [721]	valid-mape:0.08581
# [722]	valid-mape:0.08581
# [723]	valid-mape:0.08580
# [724]	valid-mape:0.08580
# [725]	valid-mape:0.08581
# [726]	valid-mape:0.08581
# [727]	valid-mape:0.08581
# [728]	valid-mape:0.08581
# [729]	valid-mape:0.08581
# [730]	valid-mape:0.08581
# [731]	valid-mape:0.08581
# [732]	valid-mape:0.08581
# [733]	valid-mape:0.08580
# [734]	valid-mape:0.08580
# [735]	valid-mape:0.08580
# [736]	valid-mape:0.08580
# [737]	valid-mape:0.08580
# [738]	valid-mape:0.08580
# [739]	valid-mape:0.08579
# [740]	valid-mape:0.08579
# [741]	valid-mape:0.08579
# [742]	valid-mape:0.08579
# [743]	valid-mape:0.08580
# [744]	valid-mape:0.08580
# [745]	valid-mape:0.08580
# [746]	valid-mape:0.08580
# [747]	valid-mape:0.08580
# [748]	valid-mape:0.08580
# [749]	valid-mape:0.08580
# [750]	valid-mape:0.08581
# [751]	valid-mape:0.08581
# [752]	valid-mape:0.08581
# [753]	valid-mape:0.08581
# [754]	valid-mape:0.08581
# [755]	valid-mape:0.08581
# [756]	valid-mape:0.08581
# [757]	valid-mape:0.08581
# [758]	valid-mape:0.08581
# [759]	valid-mape:0.08582
# [760]	valid-mape:0.08581
# [761]	valid-mape:0.08581
# [762]	valid-mape:0.08581
# [763]	valid-mape:0.08581
# [764]	valid-mape:0.08581
# [765]	valid-mape:0.08580
# [766]	valid-mape:0.08580
# [767]	valid-mape:0.08581
# [768]	valid-mape:0.08581
# [769]	valid-mape:0.08581
# [770]	valid-mape:0.08581
# [771]	valid-mape:0.08581
# [772]	valid-mape:0.08581
# [773]	valid-mape:0.08581
# [774]	valid-mape:0.08581
# [775]	valid-mape:0.08581
# [776]	valid-mape:0.08581
# [777]	valid-mape:0.08581
# [778]	valid-mape:0.08581
# [779]	valid-mape:0.08581
# [780]	valid-mape:0.08581
# [781]	valid-mape:0.08581
# [782]	valid-mape:0.08581
# [783]	valid-mape:0.08582
# [784]	valid-mape:0.08582
# [785]	valid-mape:0.08582
# [786]	valid-mape:0.08582
# [787]	valid-mape:0.08582
# [788]	valid-mape:0.08582
# [789]	valid-mape:0.08581
# [790]	valid-mape:0.08581
# [791]	valid-mape:0.08581
# [792]	valid-mape:0.08581
# [793]	valid-mape:0.08581
# [794]	valid-mape:0.08581
# [795]	valid-mape:0.08580
# [796]	valid-mape:0.08581
# [797]	valid-mape:0.08580
# [798]	valid-mape:0.08581
# [799]	valid-mape:0.08580
# [800]	valid-mape:0.08580
# [801]	valid-mape:0.08580
# [802]	valid-mape:0.08580
# [803]	valid-mape:0.08580
# [804]	valid-mape:0.08580
# [805]	valid-mape:0.08580
# [806]	valid-mape:0.08580
# [807]	valid-mape:0.08580
# [808]	valid-mape:0.08580
# [809]	valid-mape:0.08580
# [810]	valid-mape:0.08580
# [811]	valid-mape:0.08580
# [812]	valid-mape:0.08580
# [813]	valid-mape:0.08580
# [814]	valid-mape:0.08580
# [815]	valid-mape:0.08580
# [816]	valid-mape:0.08579
# [817]	valid-mape:0.08580
# [818]	valid-mape:0.08580
# [819]	valid-mape:0.08580
# [820]	valid-mape:0.08580
# [821]	valid-mape:0.08580
# [822]	valid-mape:0.08580
# [823]	valid-mape:0.08580
# [824]	valid-mape:0.08580
# [825]	valid-mape:0.08580
# [826]	valid-mape:0.08580
# [827]	valid-mape:0.08580
# [828]	valid-mape:0.08580
# [829]	valid-mape:0.08580
# [830]	valid-mape:0.08579
# [831]	valid-mape:0.08579
# [832]	valid-mape:0.08579
# [833]	valid-mape:0.08579
# [834]	valid-mape:0.08579
# [835]	valid-mape:0.08579
# [836]	valid-mape:0.08579
# [837]	valid-mape:0.08578
# [838]	valid-mape:0.08578
# [839]	valid-mape:0.08578
# [840]	valid-mape:0.08578
# [841]	valid-mape:0.08578
# [842]	valid-mape:0.08578
# [843]	valid-mape:0.08578
# [844]	valid-mape:0.08578
# [845]	valid-mape:0.08577
# [846]	valid-mape:0.08578
# [847]	valid-mape:0.08577
# [848]	valid-mape:0.08577
# [849]	valid-mape:0.08577
# [850]	valid-mape:0.08577
# [851]	valid-mape:0.08577
# [852]	valid-mape:0.08578
# [853]	valid-mape:0.08578
# [854]	valid-mape:0.08578
# [855]	valid-mape:0.08578
# [856]	valid-mape:0.08578
# [857]	valid-mape:0.08578
# [858]	valid-mape:0.08578
# [859]	valid-mape:0.08578
# [860]	valid-mape:0.08578
# [861]	valid-mape:0.08579
# [862]	valid-mape:0.08579
# [863]	valid-mape:0.08579
# [864]	valid-mape:0.08579
# [865]	valid-mape:0.08578
# [866]	valid-mape:0.08578
# [867]	valid-mape:0.08578
# [868]	valid-mape:0.08578
# [869]	valid-mape:0.08578
# [870]	valid-mape:0.08577
# [871]	valid-mape:0.08577
# [872]	valid-mape:0.08577
# [873]	valid-mape:0.08577
# [874]	valid-mape:0.08578
# [875]	valid-mape:0.08577
# [876]	valid-mape:0.08577
# [877]	valid-mape:0.08577
# [878]	valid-mape:0.08577
# [879]	valid-mape:0.08577
# [880]	valid-mape:0.08577
# [881]	valid-mape:0.08577
# [882]	valid-mape:0.08577
# [883]	valid-mape:0.08577
# [884]	valid-mape:0.08577
# [885]	valid-mape:0.08577
# [886]	valid-mape:0.08577
# [887]	valid-mape:0.08577
# [888]	valid-mape:0.08576
# [889]	valid-mape:0.08577
# [890]	valid-mape:0.08577
# [891]	valid-mape:0.08578
# [892]	valid-mape:0.08577
# [893]	valid-mape:0.08578
# [894]	valid-mape:0.08578
# [895]	valid-mape:0.08578
# [896]	valid-mape:0.08578
# [897]	valid-mape:0.08578
# [898]	valid-mape:0.08578
# [899]	valid-mape:0.08578
# [900]	valid-mape:0.08578
# [901]	valid-mape:0.08578
# [902]	valid-mape:0.08577
# [903]	valid-mape:0.08577
# [904]	valid-mape:0.08577
# [905]	valid-mape:0.08577
# [906]	valid-mape:0.08577
# [907]	valid-mape:0.08577
# [908]	valid-mape:0.08576
# [909]	valid-mape:0.08577
# [910]	valid-mape:0.08577
# [911]	valid-mape:0.08577
# [912]	valid-mape:0.08577
# [913]	valid-mape:0.08576
# [914]	valid-mape:0.08576
# [915]	valid-mape:0.08576
# [916]	valid-mape:0.08576
# [917]	valid-mape:0.08576
# [918]	valid-mape:0.08576
# [919]	valid-mape:0.08576
# [920]	valid-mape:0.08576
# [921]	valid-mape:0.08576
# [922]	valid-mape:0.08576
# [923]	valid-mape:0.08576
# [924]	valid-mape:0.08576
# [925]	valid-mape:0.08576
# [926]	valid-mape:0.08576
# [927]	valid-mape:0.08576
# [928]	valid-mape:0.08575
# [929]	valid-mape:0.08575
# [930]	valid-mape:0.08575
# [931]	valid-mape:0.08575
# [932]	valid-mape:0.08575
# [933]	valid-mape:0.08575
# [934]	valid-mape:0.08575
# [935]	valid-mape:0.08575
# [936]	valid-mape:0.08575
# [937]	valid-mape:0.08575
# [938]	valid-mape:0.08575
# [939]	valid-mape:0.08575
# [940]	valid-mape:0.08575
# [941]	valid-mape:0.08575
# [942]	valid-mape:0.08575
# [943]	valid-mape:0.08575
# [944]	valid-mape:0.08575
# [945]	valid-mape:0.08574
# [946]	valid-mape:0.08574
# [947]	valid-mape:0.08574
# [948]	valid-mape:0.08574
# [949]	valid-mape:0.08574
# [950]	valid-mape:0.08574
# [951]	valid-mape:0.08574
# [952]	valid-mape:0.08574
# [953]	valid-mape:0.08573
# [954]	valid-mape:0.08573
# [955]	valid-mape:0.08573
# [956]	valid-mape:0.08573
# [957]	valid-mape:0.08574
# [958]	valid-mape:0.08574
# [959]	valid-mape:0.08574
# [960]	valid-mape:0.08574
# [961]	valid-mape:0.08574
# [962]	valid-mape:0.08574
# [963]	valid-mape:0.08574
# [964]	valid-mape:0.08574
# [965]	valid-mape:0.08574
# [966]	valid-mape:0.08574
# [967]	valid-mape:0.08575
# [968]	valid-mape:0.08575
# [969]	valid-mape:0.08574
# [970]	valid-mape:0.08574
# [971]	valid-mape:0.08574
# [972]	valid-mape:0.08574
# [973]	valid-mape:0.08574
# [974]	valid-mape:0.08574
# [975]	valid-mape:0.08574
# [976]	valid-mape:0.08574
# [977]	valid-mape:0.08574
# [978]	valid-mape:0.08574
# [979]	valid-mape:0.08574
# [980]	valid-mape:0.08574
# [981]	valid-mape:0.08574
# [982]	valid-mape:0.08574
# [983]	valid-mape:0.08574
# [984]	valid-mape:0.08575
# [985]	valid-mape:0.08574
# [986]	valid-mape:0.08574
# [987]	valid-mape:0.08574
# [988]	valid-mape:0.08574
# [989]	valid-mape:0.08574
# [990]	valid-mape:0.08574
# [991]	valid-mape:0.08574
# [992]	valid-mape:0.08574
# [993]	valid-mape:0.08574
# [994]	valid-mape:0.08574
# [995]	valid-mape:0.08574
# [996]	valid-mape:0.08574
# [997]	valid-mape:0.08574
# [998]	valid-mape:0.08574
# [999]	valid-mape:0.08574
# [1000]	valid-mape:0.08575
# [1001]	valid-mape:0.08575
# [1002]	valid-mape:0.08574
# [1003]	valid-mape:0.08574
# [1004]	valid-mape:0.08574
# [1005]	valid-mape:0.08574
# [1006]	valid-mape:0.08574
# [1007]	valid-mape:0.08574
# [1008]	valid-mape:0.08575
# [1009]	valid-mape:0.08574
# [1010]	valid-mape:0.08575
# [1011]	valid-mape:0.08575
# [1012]	valid-mape:0.08575
# [1013]	valid-mape:0.08575
# [1014]	valid-mape:0.08575
# [1015]	valid-mape:0.08575
# [1016]	valid-mape:0.08575
# [1017]	valid-mape:0.08574
# [1018]	valid-mape:0.08574
# [1019]	valid-mape:0.08574
# [1020]	valid-mape:0.08574
# [1021]	valid-mape:0.08574
# [1022]	valid-mape:0.08574
# [1023]	valid-mape:0.08574
# [1024]	valid-mape:0.08574
# [1025]	valid-mape:0.08574
# [1026]	valid-mape:0.08574
# [1027]	valid-mape:0.08574
# [1028]	valid-mape:0.08574
# [1029]	valid-mape:0.08574
# [1030]	valid-mape:0.08574
# [1031]	valid-mape:0.08574
# [1032]	valid-mape:0.08574
# [1033]	valid-mape:0.08574
# [1034]	valid-mape:0.08573
# [1035]	valid-mape:0.08573
# [1036]	valid-mape:0.08573
# [1037]	valid-mape:0.08573
# [1038]	valid-mape:0.08573
# [1039]	valid-mape:0.08573
# [1040]	valid-mape:0.08573
# [1041]	valid-mape:0.08573
# [1042]	valid-mape:0.08573
# [1043]	valid-mape:0.08573
# [1044]	valid-mape:0.08573
# [1045]	valid-mape:0.08573
# [1046]	valid-mape:0.08573
# [1047]	valid-mape:0.08573
# [1048]	valid-mape:0.08573
# [1049]	valid-mape:0.08573
# [1050]	valid-mape:0.08573
# [1051]	valid-mape:0.08573
# [1052]	valid-mape:0.08573
# [1053]	valid-mape:0.08572
# [1054]	valid-mape:0.08572
# [1055]	valid-mape:0.08572
# [1056]	valid-mape:0.08572
# [1057]	valid-mape:0.08573
# [1058]	valid-mape:0.08573
# [1059]	valid-mape:0.08573
# [1060]	valid-mape:0.08572
# [1061]	valid-mape:0.08572
# [1062]	valid-mape:0.08572
# [1063]	valid-mape:0.08572
# [1064]	valid-mape:0.08572
# [1065]	valid-mape:0.08572
# [1066]	valid-mape:0.08572
# [1067]	valid-mape:0.08572
# [1068]	valid-mape:0.08572
# [1069]	valid-mape:0.08573
# [1070]	valid-mape:0.08573
# [1071]	valid-mape:0.08572
# [1072]	valid-mape:0.08572
# [1073]	valid-mape:0.08573
# [1074]	valid-mape:0.08573
# [1075]	valid-mape:0.08573
# [1076]	valid-mape:0.08573
# [1077]	valid-mape:0.08573
# [1078]	valid-mape:0.08573
# [1079]	valid-mape:0.08573
# [1080]	valid-mape:0.08573
# [1081]	valid-mape:0.08573
# [1082]	valid-mape:0.08573
# [1083]	valid-mape:0.08572
# [1084]	valid-mape:0.08572
# [1085]	valid-mape:0.08572
# [1086]	valid-mape:0.08572
# [1087]	valid-mape:0.08572
# [1088]	valid-mape:0.08572
# [1089]	valid-mape:0.08572
# [1090]	valid-mape:0.08572
# [1091]	valid-mape:0.08573
# [1092]	valid-mape:0.08573
# [1093]	valid-mape:0.08573
# [1094]	valid-mape:0.08572
# [1095]	valid-mape:0.08572
# [1096]	valid-mape:0.08572
# [1097]	valid-mape:0.08572
# [1098]	valid-mape:0.08572
# [1099]	valid-mape:0.08572
# [1100]	valid-mape:0.08573
# [1101]	valid-mape:0.08572
# [1102]	valid-mape:0.08572
# [1103]	valid-mape:0.08572
# [1104]	valid-mape:0.08572
# [1105]	valid-mape:0.08572
# [1106]	valid-mape:0.08572
# [1107]	valid-mape:0.08572
# [1108]	valid-mape:0.08572
# [1109]	valid-mape:0.08572
# [1110]	valid-mape:0.08572
# [1111]	valid-mape:0.08572
# [1112]	valid-mape:0.08572
# [1113]	valid-mape:0.08572
# [1114]	valid-mape:0.08571
# [1115]	valid-mape:0.08571
# [1116]	valid-mape:0.08571
# [1117]	valid-mape:0.08571
# [1118]	valid-mape:0.08571
# [1119]	valid-mape:0.08571
# [1120]	valid-mape:0.08571
# [1121]	valid-mape:0.08571
# [1122]	valid-mape:0.08571
# [1123]	valid-mape:0.08571
# [1124]	valid-mape:0.08571
# [1125]	valid-mape:0.08571
# [1126]	valid-mape:0.08571
# [1127]	valid-mape:0.08571
# [1128]	valid-mape:0.08571
# [1129]	valid-mape:0.08571
# [1130]	valid-mape:0.08571
# [1131]	valid-mape:0.08571
# [1132]	valid-mape:0.08570
# [1133]	valid-mape:0.08570
# [1134]	valid-mape:0.08570
# [1135]	valid-mape:0.08570
# [1136]	valid-mape:0.08570
# [1137]	valid-mape:0.08570
# [1138]	valid-mape:0.08570
# [1139]	valid-mape:0.08570
# [1140]	valid-mape:0.08570
# [1141]	valid-mape:0.08570
# [1142]	valid-mape:0.08570
# [1143]	valid-mape:0.08570
# [1144]	valid-mape:0.08570
# [1145]	valid-mape:0.08570
# [1146]	valid-mape:0.08570
# [1147]	valid-mape:0.08570
# [1148]	valid-mape:0.08570
# [1149]	valid-mape:0.08570
# [1150]	valid-mape:0.08570
# [1151]	valid-mape:0.08570
# [1152]	valid-mape:0.08570
# [1153]	valid-mape:0.08570
# [1154]	valid-mape:0.08570
# [1155]	valid-mape:0.08570
# [1156]	valid-mape:0.08570
# [1157]	valid-mape:0.08570
# [1158]	valid-mape:0.08569
# [1159]	valid-mape:0.08569
# [1160]	valid-mape:0.08569
# [1161]	valid-mape:0.08569
# [1162]	valid-mape:0.08569
# [1163]	valid-mape:0.08570
# [1164]	valid-mape:0.08570
# [1165]	valid-mape:0.08570
# [1166]	valid-mape:0.08570
# [1167]	valid-mape:0.08570
# [1168]	valid-mape:0.08570
# [1169]	valid-mape:0.08570
# [1170]	valid-mape:0.08570
# [1171]	valid-mape:0.08570
# [1172]	valid-mape:0.08570
# [1173]	valid-mape:0.08570
# [1174]	valid-mape:0.08569
# [1175]	valid-mape:0.08569
# [1176]	valid-mape:0.08569
# [1177]	valid-mape:0.08570
# [1178]	valid-mape:0.08570
# [1179]	valid-mape:0.08569
# [1180]	valid-mape:0.08570
# [1181]	valid-mape:0.08570
# [1182]	valid-mape:0.08570
# [1183]	valid-mape:0.08570
# [1184]	valid-mape:0.08570
# [1185]	valid-mape:0.08570
# [1186]	valid-mape:0.08570
# [1187]	valid-mape:0.08570
# [1188]	valid-mape:0.08570
# [1189]	valid-mape:0.08570
# [1190]	valid-mape:0.08570
# [1191]	valid-mape:0.08570
# [1192]	valid-mape:0.08570
# [1193]	valid-mape:0.08570
# [1194]	valid-mape:0.08569
# [1195]	valid-mape:0.08569
# [1196]	valid-mape:0.08569
# [1197]	valid-mape:0.08569
# [1198]	valid-mape:0.08569
# [1199]	valid-mape:0.08569
# [1200]	valid-mape:0.08569
# [1201]	valid-mape:0.08569
# [1202]	valid-mape:0.08569
# [1203]	valid-mape:0.08570
# [1204]	valid-mape:0.08569
# [1205]	valid-mape:0.08569
# [1206]	valid-mape:0.08569
# [1207]	valid-mape:0.08569
# [1208]	valid-mape:0.08569
# [1209]	valid-mape:0.08569
# [1210]	valid-mape:0.08569
# [1211]	valid-mape:0.08569
# [1212]	valid-mape:0.08569
# [1213]	valid-mape:0.08569
# [1214]	valid-mape:0.08569
# [1215]	valid-mape:0.08569
# [1216]	valid-mape:0.08569
# [1217]	valid-mape:0.08569
# [1218]	valid-mape:0.08569
# [1219]	valid-mape:0.08569
# [1220]	valid-mape:0.08569
# [1221]	valid-mape:0.08569
# [1222]	valid-mape:0.08569
# [1223]	valid-mape:0.08569
# [1224]	valid-mape:0.08569
# [1225]	valid-mape:0.08569
# [1226]	valid-mape:0.08569
# [1227]	valid-mape:0.08569
# [1228]	valid-mape:0.08569
# [1229]	valid-mape:0.08569
# [1230]	valid-mape:0.08569
# [1231]	valid-mape:0.08569
# [1232]	valid-mape:0.08569
# [1233]	valid-mape:0.08569
# [1234]	valid-mape:0.08569
# [1235]	valid-mape:0.08569
# [1236]	valid-mape:0.08569
# [1237]	valid-mape:0.08569
# [1238]	valid-mape:0.08569
# [1239]	valid-mape:0.08569
# [1240]	valid-mape:0.08569
# [1241]	valid-mape:0.08569
# [1242]	valid-mape:0.08570
# [1243]	valid-mape:0.08570
# [1244]	valid-mape:0.08570
# [1245]	valid-mape:0.08570
# [1246]	valid-mape:0.08569
# [1247]	valid-mape:0.08569
# [1248]	valid-mape:0.08570
# [1249]	valid-mape:0.08569
# [1250]	valid-mape:0.08569
# [1251]	valid-mape:0.08569
# [1252]	valid-mape:0.08569
# [1253]	valid-mape:0.08569
# [1254]	valid-mape:0.08569
# [1255]	valid-mape:0.08569
# [1256]	valid-mape:0.08570
# [1257]	valid-mape:0.08570
# [1258]	valid-mape:0.08570
# [1259]	valid-mape:0.08570
# [1260]	valid-mape:0.08570
# [1261]	valid-mape:0.08570
# [1262]	valid-mape:0.08570
# [1263]	valid-mape:0.08570
# [1264]	valid-mape:0.08570
# [1265]	valid-mape:0.08570
# [1266]	valid-mape:0.08570
# [1267]	valid-mape:0.08570
# [1268]	valid-mape:0.08570
# [1269]	valid-mape:0.08570
# [1270]	valid-mape:0.08570
# [1271]	valid-mape:0.08570
# [1272]	valid-mape:0.08570
# [1273]	valid-mape:0.08570
# [1274]	valid-mape:0.08570
# [1275]	valid-mape:0.08570
# [1276]	valid-mape:0.08570
# [1277]	valid-mape:0.08570
# [1278]	valid-mape:0.08570
# [1279]	valid-mape:0.08570
# [1280]	valid-mape:0.08570
# [1281]	valid-mape:0.08570
# [1282]	valid-mape:0.08570
# [1283]	valid-mape:0.08570
# [1284]	valid-mape:0.08570
# [1285]	valid-mape:0.08570
# [1286]	valid-mape:0.08570
# [1287]	valid-mape:0.08570
# [1288]	valid-mape:0.08570
# [1289]	valid-mape:0.08570
# [1290]	valid-mape:0.08570
# [1291]	valid-mape:0.08570
# [1292]	valid-mape:0.08570
# [1293]	valid-mape:0.08570
# [1294]	valid-mape:0.08570
# [1295]	valid-mape:0.08570
# [1296]	valid-mape:0.08570
# [1297]	valid-mape:0.08570
# [1298]	valid-mape:0.08570
# [1299]	valid-mape:0.08570
# [1300]	valid-mape:0.08570
# [1301]	valid-mape:0.08570
# [1302]	valid-mape:0.08570
# [1303]	valid-mape:0.08570
# [1304]	valid-mape:0.08570
# [1305]	valid-mape:0.08570
# [1306]	valid-mape:0.08570
# [1307]	valid-mape:0.08570
# [1308]	valid-mape:0.08570
# [1309]	valid-mape:0.08570
# [1310]	valid-mape:0.08570
# [1311]	valid-mape:0.08570
# [1312]	valid-mape:0.08570
# [1313]	valid-mape:0.08570
# [1314]	valid-mape:0.08570
# [1315]	valid-mape:0.08570
# [1316]	valid-mape:0.08570
# [1317]	valid-mape:0.08570
# [1318]	valid-mape:0.08570
# [1319]	valid-mape:0.08569
# [1320]	valid-mape:0.08569
# [1321]	valid-mape:0.08570
# [1322]	valid-mape:0.08570
# [1323]	valid-mape:0.08570
# [1324]	valid-mape:0.08570
# [1325]	valid-mape:0.08570
# [1326]	valid-mape:0.08570
# [1327]	valid-mape:0.08570
# [1328]	valid-mape:0.08570
# [1329]	valid-mape:0.08570
# [1330]	valid-mape:0.08570
# [1331]	valid-mape:0.08570
# [1332]	valid-mape:0.08570
# [1333]	valid-mape:0.08570
# [1334]	valid-mape:0.08570
# [1335]	valid-mape:0.08570
# [1336]	valid-mape:0.08570
# [1337]	valid-mape:0.08570
# [1338]	valid-mape:0.08570
# [1339]	valid-mape:0.08570
# [1340]	valid-mape:0.08570
# [1341]	valid-mape:0.08570
# [1342]	valid-mape:0.08570
# [1343]	valid-mape:0.08570
# [1344]	valid-mape:0.08570
# [1345]	valid-mape:0.08570
# [1346]	valid-mape:0.08570
# [1347]	valid-mape:0.08570
# [1348]	valid-mape:0.08570
# [1349]	valid-mape:0.08570
# [1350]	valid-mape:0.08570
# [1351]	valid-mape:0.08570
# [1352]	valid-mape:0.08570
# [1353]	valid-mape:0.08570
# [1354]	valid-mape:0.08570
# [1355]	valid-mape:0.08570
# [1356]	valid-mape:0.08570
# [1357]	valid-mape:0.08570
# [1358]	valid-mape:0.08570
# [1359]	valid-mape:0.08570
# [1360]	valid-mape:0.08570
# [1361]	valid-mape:0.08570
# [1362]	valid-mape:0.08570
# [1363]	valid-mape:0.08570
# [1364]	valid-mape:0.08570
# [1365]	valid-mape:0.08570
# [1366]	valid-mape:0.08570
# [1367]	valid-mape:0.08570
# [1368]	valid-mape:0.08570
# [1369]	valid-mape:0.08570
# [1370]	valid-mape:0.08570
# [1371]	valid-mape:0.08570
# [1372]	valid-mape:0.08570
# [1373]	valid-mape:0.08570
# [1374]	valid-mape:0.08570
# [1375]	valid-mape:0.08570
# [1376]	valid-mape:0.08570
# [1377]	valid-mape:0.08570
# [1378]	valid-mape:0.08570
# [1379]	valid-mape:0.08570
# [1380]	valid-mape:0.08570
# [1381]	valid-mape:0.08570
# [1382]	valid-mape:0.08570
# [1383]	valid-mape:0.08570
# [1384]	valid-mape:0.08570
# [1385]	valid-mape:0.08570
# [1386]	valid-mape:0.08570
# [1387]	valid-mape:0.08570
# [1388]	valid-mape:0.08570
# [1389]	valid-mape:0.08570
# [1390]	valid-mape:0.08570
# [1391]	valid-mape:0.08570
# [1392]	valid-mape:0.08570
# [1393]	valid-mape:0.08570
# [1394]	valid-mape:0.08570
# [1395]	valid-mape:0.08570
# [1396]	valid-mape:0.08570
# [1397]	valid-mape:0.08570
# [1398]	valid-mape:0.08570
# [1399]	valid-mape:0.08570
# [1400]	valid-mape:0.08570
# [1401]	valid-mape:0.08570
# [1402]	valid-mape:0.08570
# [1403]	valid-mape:0.08570
# [1404]	valid-mape:0.08570
# [1405]	valid-mape:0.08570
# [1406]	valid-mape:0.08570
# [1407]	valid-mape:0.08571
# [1408]	valid-mape:0.08571
# [1409]	valid-mape:0.08571
# [1410]	valid-mape:0.08571
# [1411]	valid-mape:0.08571
# [1412]	valid-mape:0.08570
# [1413]	valid-mape:0.08570
# [1414]	valid-mape:0.08570
# [1415]	valid-mape:0.08570
# [1416]	valid-mape:0.08570
# [1417]	valid-mape:0.08570
# [1418]	valid-mape:0.08570
# [1419]	valid-mape:0.08570
# [1420]	valid-mape:0.08571
# [1421]	valid-mape:0.08571
# [1422]	valid-mape:0.08571
# [1423]	valid-mape:0.08571
# [1424]	valid-mape:0.08571
# [1425]	valid-mape:0.08570
# [1426]	valid-mape:0.08570
# [1427]	valid-mape:0.08570
# [1428]	valid-mape:0.08570
# [1429]	valid-mape:0.08570
# [1430]	valid-mape:0.08570
# [1431]	valid-mape:0.08570
# [1432]	valid-mape:0.08570
# [1433]	valid-mape:0.08570
# [1434]	valid-mape:0.08570
# [1435]	valid-mape:0.08570
# [1436]	valid-mape:0.08570
# [1437]	valid-mape:0.08570
# [1438]	valid-mape:0.08570
# [1439]	valid-mape:0.08570
# [1440]	valid-mape:0.08570
# [1441]	valid-mape:0.08570
# [1442]	valid-mape:0.08570
# [1443]	valid-mape:0.08570
# [1444]	valid-mape:0.08570
# [1445]	valid-mape:0.08570
# [1446]	valid-mape:0.08570
# [1447]	valid-mape:0.08570
# [1448]	valid-mape:0.08570
# [1449]	valid-mape:0.08570
# [1450]	valid-mape:0.08570
# [1451]	valid-mape:0.08570
# [1452]	valid-mape:0.08570
# [1453]	valid-mape:0.08570
# [1454]	valid-mape:0.08570
# [1455]	valid-mape:0.08570
# [1456]	valid-mape:0.08570
# [1457]	valid-mape:0.08570
# [1458]	valid-mape:0.08570
# [1459]	valid-mape:0.08571
# [1460]	valid-mape:0.08570
# [1461]	valid-mape:0.08570
# [1462]	valid-mape:0.08571
# [1463]	valid-mape:0.08571
# [1464]	valid-mape:0.08571
# [1465]	valid-mape:0.08571
# [1466]	valid-mape:0.08571
# [1467]	valid-mape:0.08571
# [1468]	valid-mape:0.08571
# [1469]	valid-mape:0.08570
# [1470]	valid-mape:0.08570
# [1471]	valid-mape:0.08570
# [1472]	valid-mape:0.08570
# [1473]	valid-mape:0.08570
# [1474]	valid-mape:0.08570
# [1475]	valid-mape:0.08570
# [1476]	valid-mape:0.08570
# [1477]	valid-mape:0.08570
# [1478]	valid-mape:0.08570
# [1479]	valid-mape:0.08570
# [1480]	valid-mape:0.08571
# [1481]	valid-mape:0.08571
# [1482]	valid-mape:0.08571
# [1483]	valid-mape:0.08570
# [1484]	valid-mape:0.08570
# [1485]	valid-mape:0.08570
# [1486]	valid-mape:0.08570
# [1487]	valid-mape:0.08570
# [1488]	valid-mape:0.08570
# [1489]	valid-mape:0.08570
# [1490]	valid-mape:0.08570
# [1491]	valid-mape:0.08570
# [1492]	valid-mape:0.08570
# [1493]	valid-mape:0.08570
# [1494]	valid-mape:0.08570
# [1495]	valid-mape:0.08570
# [1496]	valid-mape:0.08570
# [1497]	valid-mape:0.08570
# [1498]	valid-mape:0.08570
# [1499]	valid-mape:0.08570
# [1500]	valid-mape:0.08570
# [1501]	valid-mape:0.08570
# [1502]	valid-mape:0.08570
# [1503]	valid-mape:0.08570
# [1504]	valid-mape:0.08570
# [1505]	valid-mape:0.08570
# [1506]	valid-mape:0.08570
# [1507]	valid-mape:0.08570
# [1508]	valid-mape:0.08570
# [1509]	valid-mape:0.08570
# [1510]	valid-mape:0.08570
# [1511]	valid-mape:0.08570
# [1512]	valid-mape:0.08570
# [1513]	valid-mape:0.08570
# [1514]	valid-mape:0.08570
# [1515]	valid-mape:0.08570
# [1516]	valid-mape:0.08570
# [1517]	valid-mape:0.08570
# [1518]	valid-mape:0.08570
# [1519]	valid-mape:0.08570
# [1520]	valid-mape:0.08570
# [1521]	valid-mape:0.08570
# [1522]	valid-mape:0.08570
# [1523]	valid-mape:0.08570
# [1524]	valid-mape:0.08570
# [1525]	valid-mape:0.08570
# [1526]	valid-mape:0.08570
# [1527]	valid-mape:0.08570
# [1528]	valid-mape:0.08570
# [1529]	valid-mape:0.08570
# [1530]	valid-mape:0.08570
# [1531]	valid-mape:0.08570
# [1532]	valid-mape:0.08570
# [1533]	valid-mape:0.08570
# [1534]	valid-mape:0.08570
# [1535]	valid-mape:0.08570
# [1536]	valid-mape:0.08570
# [1537]	valid-mape:0.08570
# [1538]	valid-mape:0.08570
# [1539]	valid-mape:0.08570
# [1540]	valid-mape:0.08570
# [1541]	valid-mape:0.08570
# [1542]	valid-mape:0.08570
# [1543]	valid-mape:0.08570
# [1544]	valid-mape:0.08570
# [1545]	valid-mape:0.08570
# [1546]	valid-mape:0.08570
# [1547]	valid-mape:0.08570
# [1548]	valid-mape:0.08570
# [1549]	valid-mape:0.08570
# [1550]	valid-mape:0.08570
# [1551]	valid-mape:0.08570
# [1552]	valid-mape:0.08570
# [1553]	valid-mape:0.08570
# [1554]	valid-mape:0.08570
# [1555]	valid-mape:0.08570
# [1556]	valid-mape:0.08570
# [1557]	valid-mape:0.08570
# [1558]	valid-mape:0.08570
# [1559]	valid-mape:0.08570
# [1560]	valid-mape:0.08570
# [1561]	valid-mape:0.08570
# [1562]	valid-mape:0.08570
# [1563]	valid-mape:0.08570
# [1564]	valid-mape:0.08570
# [1565]	valid-mape:0.08570
# [1566]	valid-mape:0.08570
# [1567]	valid-mape:0.08570
# [1568]	valid-mape:0.08570
# [1569]	valid-mape:0.08570
# [1570]	valid-mape:0.08570
# [1571]	valid-mape:0.08570
# [1572]	valid-mape:0.08570
# [1573]	valid-mape:0.08570
# [1574]	valid-mape:0.08570
# [1575]	valid-mape:0.08570
# [1576]	valid-mape:0.08570
# [1577]	valid-mape:0.08570
# [1578]	valid-mape:0.08570
# [1579]	valid-mape:0.08570
# [1580]	valid-mape:0.08570
# [1581]	valid-mape:0.08570
# [1582]	valid-mape:0.08570
# [1583]	valid-mape:0.08570
# [1584]	valid-mape:0.08570
# [1585]	valid-mape:0.08570
# [1586]	valid-mape:0.08570
# [1587]	valid-mape:0.08570
# [1588]	valid-mape:0.08570
# [1589]	valid-mape:0.08571
# [1590]	valid-mape:0.08571
# [1591]	valid-mape:0.08570
# [1592]	valid-mape:0.08571
# [1593]	valid-mape:0.08571
# [1594]	valid-mape:0.08570
# [1595]	valid-mape:0.08570
# [1596]	valid-mape:0.08570
# [1597]	valid-mape:0.08571
# [1598]	valid-mape:0.08570
# [1599]	valid-mape:0.08570
# [1600]	valid-mape:0.08570
# [1601]	valid-mape:0.08571
# [1602]	valid-mape:0.08571
# [1603]	valid-mape:0.08571
# [1604]	valid-mape:0.08571
# [1605]	valid-mape:0.08570
# [1606]	valid-mape:0.08570
# [1607]	valid-mape:0.08570
# [1608]	valid-mape:0.08570
# [1609]	valid-mape:0.08570
# [1610]	valid-mape:0.08570
# [1611]	valid-mape:0.08570
# [1612]	valid-mape:0.08570
# [1613]	valid-mape:0.08570
# [1614]	valid-mape:0.08570
# [1615]	valid-mape:0.08570
# [1616]	valid-mape:0.08570
# [1617]	valid-mape:0.08570
# [1618]	valid-mape:0.08570
# [1619]	valid-mape:0.08570
# [1620]	valid-mape:0.08570
# [1621]	valid-mape:0.08570
# [1622]	valid-mape:0.08570
# [1623]	valid-mape:0.08570
# [1624]	valid-mape:0.08570
# [1625]	valid-mape:0.08570
# [1626]	valid-mape:0.08570
# [1627]	valid-mape:0.08570
# [1628]	valid-mape:0.08570
# [1629]	valid-mape:0.08570
# [1630]	valid-mape:0.08570
# [1631]	valid-mape:0.08570
# [1632]	valid-mape:0.08570
# [1633]	valid-mape:0.08570
# [1634]	valid-mape:0.08570
# [1635]	valid-mape:0.08570
# [1636]	valid-mape:0.08570
# [1637]	valid-mape:0.08570
# [1638]	valid-mape:0.08570
# [1639]	valid-mape:0.08570
# [1640]	valid-mape:0.08570
# [1641]	valid-mape:0.08570
# [1642]	valid-mape:0.08570
# [1643]	valid-mape:0.08570
# [1644]	valid-mape:0.08570
# [1645]	valid-mape:0.08570
# [1646]	valid-mape:0.08570
# [1647]	valid-mape:0.08570
# [1648]	valid-mape:0.08570
# [1649]	valid-mape:0.08570
# [1650]	valid-mape:0.08570
# [1651]	valid-mape:0.08570
# [1652]	valid-mape:0.08570
# [1653]	valid-mape:0.08570
# [1654]	valid-mape:0.08570
# [1655]	valid-mape:0.08570
# [1656]	valid-mape:0.08570
# [1657]	valid-mape:0.08570
# [1658]	valid-mape:0.08570
# [1659]	valid-mape:0.08570
# [1660]	valid-mape:0.08570
# [1661]	valid-mape:0.08570
# [1662]	valid-mape:0.08570
# [1663]	valid-mape:0.08570
# [1664]	valid-mape:0.08570
# [1665]	valid-mape:0.08570
# [1666]	valid-mape:0.08570
# [1667]	valid-mape:0.08570
# [1668]	valid-mape:0.08570
# [1669]	valid-mape:0.08570
# [1670]	valid-mape:0.08570
# [1671]	valid-mape:0.08570
# [1672]	valid-mape:0.08570
# [1673]	valid-mape:0.08570
# [1674]	valid-mape:0.08570
# [1675]	valid-mape:0.08570
# [1676]	valid-mape:0.08570
# [1677]	valid-mape:0.08570
# [1678]	valid-mape:0.08570
# [1679]	valid-mape:0.08570
# [1680]	valid-mape:0.08570
# [1681]	valid-mape:0.08570
# [1682]	valid-mape:0.08570
# [1683]	valid-mape:0.08570
# [1684]	valid-mape:0.08570
# [1685]	valid-mape:0.08570
# [1686]	valid-mape:0.08570
# [1687]	valid-mape:0.08570
# [1688]	valid-mape:0.08570
# [1689]	valid-mape:0.08570
# [1690]	valid-mape:0.08570
# [1691]	valid-mape:0.08570
# [1692]	valid-mape:0.08570
# [1693]	valid-mape:0.08570
# [1694]	valid-mape:0.08570
# [1695]	valid-mape:0.08570
# [1696]	valid-mape:0.08570
# [1697]	valid-mape:0.08570
# [1698]	valid-mape:0.08570
# [1699]	valid-mape:0.08570
# [1700]	valid-mape:0.08570
# [1701]	valid-mape:0.08570
# [1702]	valid-mape:0.08570
# [1703]	valid-mape:0.08570
# [1704]	valid-mape:0.08570
# [1705]	valid-mape:0.08570
# [1706]	valid-mape:0.08570
# [1707]	valid-mape:0.08570
# [1708]	valid-mape:0.08570
# [1709]	valid-mape:0.08570
# [1710]	valid-mape:0.08570
# [1711]	valid-mape:0.08570
# [1712]	valid-mape:0.08570
# [1713]	valid-mape:0.08570
# [1714]	valid-mape:0.08570
# [1715]	valid-mape:0.08570
# [1716]	valid-mape:0.08570
# [1717]	valid-mape:0.08570
# [1718]	valid-mape:0.08570
# [1719]	valid-mape:0.08570
# [1720]	valid-mape:0.08570
# [1721]	valid-mape:0.08570
# [1722]	valid-mape:0.08570
# [1723]	valid-mape:0.08570
# [1724]	valid-mape:0.08570
# [1725]	valid-mape:0.08570
# [1726]	valid-mape:0.08570
# [1727]	valid-mape:0.08570
# [1728]	valid-mape:0.08570
# [1729]	valid-mape:0.08570
# [1730]	valid-mape:0.08570
# [1731]	valid-mape:0.08570

# %%
# Testing data
X_test = test_df
w1 = 1.0
w2 = 0.0

test_pred_xgb = xgbmodel.predict(xgb.DMatrix(X_test), ntree_limit = xgbmodel.best_ntree_limit).tolist()
test_pred = np.asarray(w1) * test_pred_xgb

submission = pd.DataFrame()
submission['ID'] = test_sb['ID']
submission['predicted_price'] = test_pred
submission.to_csv(submit_file, index=False)
# Out:
# /Users/jellyfish/anaconda3/envs/test/lib/python3.11/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
valid_pred_xgb = xgbmodel.predict(xgb.DMatrix(X_valid), ntree_limit = xgbmodel.best_ntree_limit).tolist()
valid_pred = np.asarray(w1) * valid_pred_xgb
print("MAPE:", mape_loss(y_valid, valid_pred))
# Out:
# MAPE: 8.568822223464217
# /Users/jellyfish/anaconda3/envs/test/lib/python3.11/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
